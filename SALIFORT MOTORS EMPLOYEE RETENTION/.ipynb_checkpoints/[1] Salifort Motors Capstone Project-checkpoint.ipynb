# %% [markdown]
# # **Salifort Motors Employee Retention Data Analytics Project**

# %% [markdown]
# **Analyst:** John Cedrick V. Napa
# **Date:** March 15, 2024

# %% [markdown]
# ## **Project Overview**
#
# - **Client/Stakeholders:** Salifort Motors HR Department and Senior Leadership Team.
# - **Statement of the Problem:** High turnover rate of Salifort Employees
# - **Purpose of the Analysis:** Understand the factors affecting employee retention and decrease the turnover rate of Salifort Motors employees.
#
# **Background:**
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. As the data analytics professional, provide data-driven suggestions based on your understanding of the data.

# %% [markdown]
# ## **Data Overview:**
# - **Data Source:** Human Resource Survey
# - **Data File Name:** HR_capstone_dataset.csv
# - **Data Size:** 14,999 rows x 10 columns
# - **Dataset Kaggle Link:** [Kaggle](https://www.kaggle.com/datasets/mfaisalqureshi/hr-analytics-and-job-prediction?select=HR_comma_sep.csv).
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)olumns

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # **A. Planning Phase**
# ### Goals/Milestones:
# - Analyze Data and Perform Exploratory Data Analysis
# - Identify Variables affecting employee turnover
# - Create Machine Learning Models
# - Evaluate Models
# - Interpret Results and Recommend Course of Action

# %% [markdown]
# ### Import packages

# %%
from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

# %%
# Data Manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Analysis
import scipy.stats as stats
import statsmodels.api as sm

# Data Modeling
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance

# Helper Modules
from sklearn.model_selection import train_test_split, GridSearchCV
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.tree import plot_tree

import pickle

# %% [markdown]
# ### Load dataset

# %%
# Load dataset into a dataframe
df0 = pd.read_csv("HR_capstone_dataset.csv")
df0 = df0.replace([np.inf, -np.inf], np.nan)
df0.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # **B. Data Exploration (Initial EDA and data cleaning)**
#
# - Understand variables
# - Clean dataset (missing data, redundant data, outliers)

# %%
# Gather basic information about the data
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# Gather basic information about the data
df0.describe(include='all')
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# count         14999.000000     14999.000000    14999.000000
# unique                 NaN              NaN             NaN
# top                    NaN              NaN             NaN
# freq                   NaN              NaN             NaN
# mean              0.612834         0.716102        3.803054
# std               0.248631         0.171169        1.232592
# min               0.090000         0.360000        2.000000
# 25%               0.440000         0.560000        3.000000
# 50%               0.640000         0.720000        4.000000
# 75%               0.820000         0.870000        5.000000
# max               1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# ...

# %%
# Gather descriptive statistics about the data
df0.describe(include='all')
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# count         14999.000000     14999.000000    14999.000000
# unique                 NaN              NaN             NaN
# top                    NaN              NaN             NaN
# freq                   NaN              NaN             NaN
# mean              0.612834         0.716102        3.803054
# std               0.248631         0.171169        1.232592
# min               0.090000         0.360000        2.000000
# 25%               0.440000         0.560000        3.000000
# 50%               0.640000         0.720000        4.000000
# 75%               0.820000         0.870000        5.000000
# max               1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# ...

# %% [markdown]
# ## Column name standardization

# %%
# Display all column names
df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# Rename columns as needed
# Mispelled and snake_case changes
df0 = df0.rename(columns={'Work_accident':'work_accident',
                          'Department':'department',
                          'time_spend_company':'tenure',
                          'average_montly_hours':'average_monthly_hours'})
df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'tenure', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %% [markdown]
# ## Missing values
# Check for any missing values in the data.

# %%
# Check for missing values
df0.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_monthly_hours    0
# tenure                   0
# work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %% [markdown]
# ## Duplicates
# Check for any duplicate entries in the data.

# %%
# Check for duplicates
df0.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995     True
# 14996     True
# 14997     True
# 14998     True
# Length: 14999, dtype: bool

# %%
# Inspect some rows containing duplicates as needed
df0[df0.duplicated()]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  tenure  work_accident  left  \
# 396                      139       3              0     1
# 866                      128       3              0     1
# 1317                     127       3              0     1
# ...

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed
df1 = df0.drop_duplicates()
df1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  left  promotion_last_5years department  salary
# 0       3              0     1                      0      sales     low
# 1       6              0     1                      0      sales  medium
# 2       4              0     1                      0      sales  medium
# 3       5              0     1                      0      sales     low
# 4       3              0     1                      0      sales     low

# %% [markdown]
# ## Check outliers
# Check for outliers in the data.

# %%
# Create a boxplot to visualize distribution of `tenure` and detect any outliers
fig, axes = plt.subplots(1, 2, figsize = (12,3))
sns.boxplot(data=df1['tenure'], ax = axes[0])
axes[0].set_title('Box Plot of Tenure')
sns.histplot(data=df1['tenure'], ax = axes[1], binwidth = 0.3, discrete = True)
axes[1].set_title('Employee Tenure Distribution')
plt.show()

# %%
# Determine the number of rows containing outliers
percentile25 = df1['tenure'].quantile(0.25)
percentile75 = df1['tenure'].quantile(0.75)

iqr = percentile75 - percentile25
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

print(f'Lower Limit: {lower_limit}')
print(f'Upper Limit: {upper_limit}')

outliers = df1[(df1['tenure'] > upper_limit) | (df1['tenure'] < lower_limit)]
outliers.count()
# Out:
# Lower Limit: 1.5
# Upper Limit: 5.5
# satisfaction_level       824
# last_evaluation          824
# number_project           824
# average_monthly_hours    824
# tenure                   824
# work_accident            824
# left                     824
# promotion_last_5years    824
# department               824
# salary                   824
# dtype: int64

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # **C. Data Visualization and Analysis**

# %% [markdown]
# ## Data Balance

# %%
# Identify percentage of Personel Employment status in the 'left' column
bal = df1['left'].value_counts(normalize=True)
bal
# Out:
# left
# 0    0.833959
# 1    0.166041
# Name: proportion, dtype: float64

# %% [markdown]
# ## Data Visualizations
# Examination of variables to determine correlation

# %% [markdown]
# ### Satisfaction Level vs Number of Project

# %%
fig, axes = plt.subplots(1,2,figsize = (12,4))
sns.boxplot(data = df1, x = 'satisfaction_level', y = 'number_project', hue = 'left', orient ='h',ax = axes[0])
axes[0].set_title('Satisfaction Level per Number of project handled')
axes[0].invert_yaxis()

sns.histplot(data = df1, x = 'number_project', hue='left', ax = axes[1], multiple = 'dodge', shrink=3)
axes[1].set_title('Distribution of Employees per Number of Projects')
plt.show()

# %% [markdown]
# **Observations:**
# 1. The number of projects handled by employees significalty decreases the satisfaction level of the employees
# 2. Satisfaction levels were higher for employees handling 3-5 projects as compared to the other groups.
# 3. Proportion of employees leaving were lower for employes handling 3-4 projects

# %% [markdown]
# ### Number Projects vs. Average monthly hours

# %%
fig, axes = plt.subplots(1,2,figsize = (12,4))
sns.boxplot(data = df1, x = 'average_monthly_hours', y = 'number_project', hue = 'left', orient ='h',ax = axes[0])
axes[0].set_title('Average Monthly hours per Number of project handled')
axes[0].invert_yaxis()

sns.histplot(data = df1, x = 'number_project', hue='left', ax = axes[1], multiple = 'dodge', shrink = 4)
axes[1].set_title('Distribution of Employees per Number of Projects')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# 1. The number of projects handled by employees significalty increases the average monthly hours the employee work
# 2. A number of employees who worked shorter hours but only has 2 projects assigned to the left the company. Further investigation may be done to confirm this observations but preliminary inference is that they were probably fired
# 3. All of the employees assigned with 7 projects left the company. This may be due to overworking and burnout leading them to quit.
# 4. Employees with 3-4 projects being handled shows the best employee retention percentage as compared to other groups.
# \
# Average weekly hours:\
# 52 weeks per year; 2 weeks of vacation\
# 48 hours/week * 50 weeks/12 month = **200 hours** per month should be the average work hours
#     - almost all of the employees worked more than this.

# %% [markdown]
# ### Satisfaction Level vs Average monthly hours

# %%
plt.figure(figsize = (12,4))
sns.scatterplot(data = df1, x = 'average_monthly_hours', y = 'satisfaction_level', hue = 'left', alpha= 0.4)
plt.title('Satisfaction Level of Employees with respect to Average Monthly Hours')
plt.axvline(x=200, color='red', label='200 hrs./mo.', ls='--')
plt.legend(labels = ['200 hrs./mo.', 'stayed', 'left'])
plt.show()

# %% [markdown]
# **Observations:**
# 1. A group of level who left showing nearly zero satisfaction levels were employees with more then 250 hours average monthly hours
# 2. Another group of employees who left work within acceptable working hour range but had low satisfaction levels. There is no clear explanation to this and further examination must be conducted. One inference may be work compatibility or work pressure due to peers having to work more than the average 166.7 hours

# %% [markdown]
# ### Satisfaction Levels vs Tenure

# %%
fig, axes = plt.subplots(1,2,figsize = (12,4))
sns.boxplot(data = df1, x = 'satisfaction_level', y = 'tenure', hue = 'left', orient ='h',ax = axes[0])
axes[0].set_title('Satisfaction Level per Years Working')
axes[0].legend(title='left', loc = 'upper left')
axes[0].invert_yaxis()

sns.histplot(data = df1, x = 'tenure', hue='left', ax = axes[1], multiple = 'dodge', shrink = 8)
axes[1].set_title('Distribution of Employees with respect to number of Years in the company')
plt.show()

# %% [markdown]
# **Observations:**
# 1. Employees who worked for 4 years and left showed a very low satisfaction level which is unusual. This may be due to a year specific event, additional analysis and confirmation is needed.
# 2. Employees who has stayed for more than 7 years had high satisfaction level. may be due to salary, or the position being held.
# 3. A group of highly satisfied employees with 5-6 years of tenureship still left the company.
# 4. Employees with 2-3 years of tenureship with low to average satisfaction level left the company may be due to other oppurtunities outside the company.

# %% [markdown]
# ### Satisfaction Level vs Salary

# %%
P = df1.groupby(['salary','left'])['left'].count().reset_index(name='count')
P['Percent'] = (100 * P['count'] / P.groupby('salary')['count'].transform('sum'))
P['Percent'] = P['Percent'].apply(lambda x: '{:,.2f}%'.format(x))

# %%
fig, axes = plt.subplots(1,2,figsize = (12,6))
sns.boxplot(data = df1, x = 'satisfaction_level', y = 'salary', hue = 'left', orient ='h',ax = axes[0])
axes[0].set_title('Satisfaction Level per Salary Group')
axes[0].invert_yaxis()

sns.histplot(data = df1, x = 'salary', hue='left', ax = axes[1], multiple = 'dodge', shrink= 0.8)
axes[1].set_title('Distribution of Employees per Salary Group')
P
# Out:
#    salary  left  count Percent
# 0    high     0    942  95.15%
# 1    high     1     48   4.85%
# 2     low     0   4566  79.55%
# 3     low     1   1174  20.45%
# 4  medium     0   4492  85.38%
# 5  medium     1    769  14.62%

# %% [markdown]
# **Observations:**
# 1. There is no significant difference between sat6isfaction level across the three salary groups

# %% [markdown]
# ### Salary vs Tenure

# %%
data1 = df1[df1['tenure']<=6]
data2 = df1[df1['tenure']>6]
fig, axes = plt.subplots(1,2,figsize = (12,4))
sns.histplot(data = data1, x = 'tenure', hue='salary', ax = axes[0], multiple = 'dodge', shrink = 6,)
axes[0].set_title('Short-Tenured Employee Salary Distribution')

sns.histplot(data = data2, x = 'tenure', hue='salary', ax = axes[1], multiple = 'dodge', discrete=1, shrink = .4, 
             hue_order=['low','medium','high'])
axes[1].set_title('Long-Tenured Employee Salary Distribution')
plt.show()

# %% [markdown]
# **Observations:**
# 1. There is no significant difference of salary distribution between employees both for short and long tenured employees

# %% [markdown]
# ### Salary vs Number of Project

# %%
data1 = df1[df1['number_project']<=4]
data2 = df1[df1['number_project']>4]
fig, axes = plt.subplots(1,2,figsize = (12,4))
sns.histplot(data = data1, x = 'number_project', hue='salary', ax = axes[0], multiple = 'dodge', shrink = 7)
axes[0].set_title('Employee Salary Distribution per number of project')

sns.histplot(data = data2, x = 'number_project', hue='salary', ax = axes[1], multiple = 'dodge', discrete=1, shrink = .4, 
             hue_order=['low','medium','high'])
axes[1].set_title('Employee Salary Distribution per number of project')
plt.show()

# %% [markdown]
# **Observations:**
# 1. There is no significant difference of salary distribution of employees grouped by number of projects

# %% [markdown]
# ### Salary vs Average Monthly Hours

# %%
fig, axes = plt.subplots(1,2,figsize = (12,6))
sns.boxplot(data = df1, x = 'average_monthly_hours', y = 'salary', hue = 'left', orient ='h',ax = axes[0])
axes[0].set_title('Average Monthly hours per Number of project handled')
axes[0].invert_yaxis()

sns.histplot(data = df1, x = 'salary', hue='left', ax = axes[1], multiple = 'dodge', shrink = .7)
axes[1].set_title('Distribution of Employees per Number of Projects')
plt.show()

# %% [markdown]
# **Observations:**
# 1. There is no significant difference of average monthly hours of employees grouped by salary range

# %% [markdown]
# ### Departmental Distribution

# %%
P = df1.groupby(['department','left'])['left'].count().reset_index(name='count')
P['Percent'] = (100 * P['count'] / P.groupby('department')['count'].transform('sum'))
P['Percent'] = P['Percent'].apply(lambda x: '{:,.2f}%'.format(x))

# %%
plt.figure(figsize = (12,6))
sns.histplot(data = df1, x ='department', hue='left', multiple = 'dodge', shrink = 0.8)
plt.title('Employee Distribution per Department')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Observations:**
# 1. There is no significant difference of distribution of employee retention among departments

# %% [markdown]
# ### Last Evaluation Score vs Average Monthly Hours

# %%
plt.figure(figsize = (12,4))
sns.scatterplot(data = df1, x = 'average_monthly_hours', y = 'last_evaluation', hue = 'left', alpha = 0.3)
plt.title('Evaluation Score of Employees with respect to Average Monthly Hours')
plt.axvline(x=200, color='red', label='200 hrs./mo.', ls='--')
plt.legend(labels = ['200 hrs./mo.', 'stayed', 'left'])
plt.show()

# %% [markdown]
# **Observations:**
# 1. There are two significant groups of employees who left the company:
#     - Low evaluation score with low average hours: may have been fired or pressure from other coworkers
#     - High evaluation score with high average hours: may have quit due to overwork
# 2. Most of the employees in this company work well over 167 hours per month.
# 3. No linear correlation between hours and evaluation score; working more hours does not guarantee a high evaluation score

# %% [markdown]
# ### Promotion vs Average Monthly Hours

# %%
P = df1.groupby(['promotion_last_5years','left'])['left'].count().reset_index(name='count')
P['Percent'] = (100 * P['count'] / P.groupby('promotion_last_5years')['count'].transform('sum'))
P['Percent'] = P['Percent'].apply(lambda x: '{:,.2f}%'.format(x))
P
# Out:
#    promotion_last_5years  left  count Percent
# 0                      0     0   9805  83.18%
# 1                      0     1   1983  16.82%
# 2                      1     0    195  96.06%
# 3                      1     1      8   3.94%

# %%
plt.figure(figsize = (12,3))
sns.scatterplot(data = df1, x = 'average_monthly_hours', y = 'promotion_last_5years', hue = 'left', alpha = 0.4)
plt.title('Evaluation Score of Employees with respect to Average Monthly Hours')
plt.legend(labels = ['left','stayed'], loc = 'upper left')
plt.show()

# %% [markdown]
# **Observations:**
# 1. very few were promoted in the last 5 years (only 203 employees)
# 2. promotion is not highly dependent on average monthly hours
# 3. Most people who left worked overtime

# %% [markdown]
# ### **Correlation Heatmap**

# %%
df1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  left  promotion_last_5years department  salary
# 0       3              0     1                      0      sales     low
# 1       6              0     1                      0      sales  medium
# 2       4              0     1                      0      sales  medium
# 3       5              0     1                      0      sales     low
# 4       3              0     1                      0      sales     low

# %%
plt.figure(figsize = (8,4))
sns.heatmap(data = df1[['satisfaction_level','last_evaluation','number_project','average_monthly_hours','tenure','promotion_last_5years']].corr(), 
            vmin = -1, vmax = 1, annot = True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
plt.show()

# %% [markdown]
# **Observations:**
# 1. Positive Correlation between evaluation score, number of project and average work hours
# 2. Negative Correlation was observed for satisfaction level and whether an employee leaves.

# %% [markdown]
# ### **Summary of Insights**

# %% [markdown]
# From the plots created here are the insights infered:
# - Employee retention is highly influenced by the work environment and the load of individuals. The average work hours and the number of projects handled can have an effect to whether an employee would stay or leave the company. These observations was clearly reflected by the satisfaction levels of the employees.
# - Significant number of employees work overtime often leading to burnout; working more than **166.67** hours per month
# - Employees who have been with the company for more than 6 years tend to stay.
#
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # **D. Model Building**
# - Fit a model that predicts the outcome variable using two or more independent variables
# - Check model assumptions
# - Evaluate the model

# %% [markdown]
# ## Regression Machine Learning Identification
# 1. **✗** Linear Regression: Output is categorical
# 2. **✓** Logistic Binomial Regression

# %% [markdown]
# ### Modeling (Logistic Regression)

# %% [markdown]
# #### **Logistic Binomial Regression Modeling**
# Data Cleaning and Preparation

# %%
## Encode categorical values to category datatype
### Create new DataFrame for encoding
df_enc = df1.copy()
### Convert columns to Categorical
df_enc['department'] = df_enc['department'].astype('category')
#df_enc['salary'] = pd.Categorical(df_enc['salary'],categories=['low', 'medium', 'high'], ordered = True)
df_enc['salary'] = (df_enc['salary'].astype('category').cat.set_categories(['low', 'medium', 'high']).cat.codes)
### Encode
df_enc = pd.get_dummies(df_enc, drop_first = False)

# %%
## Check linear correlation using a heatmap
plt.figure(figsize = (8,4))
sns.heatmap(data = df_enc[['satisfaction_level','last_evaluation','number_project','average_monthly_hours','tenure']].corr(), 
            vmin = -1, vmax = 1, annot = True, cmap=sns.color_palette("vlag", as_cmap=True))
plt.show()

# %%
#Remove previously determined outliers due to sensitivity of the model.
percentile25 = df_enc['tenure'].quantile(0.25)
percentile75 = df_enc['tenure'].quantile(0.75)

iqr = percentile75 - percentile25
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

df_enc_logreg = df_enc[(df_enc['tenure'] <= upper_limit) & (df_enc['tenure'] >= lower_limit)]

# %%
#Isolation of dependent variable
y = df_enc_logreg['left']

# %%
#Isolation of independent variable
X = df_enc_logreg.drop('left', axis = 1)

# %%
#Check Balance of Dependent Variable
df_enc_logreg['left'].value_counts()
df_enc_logreg['left'].value_counts(normalize=True)
# Out:
# left
# 0    0.831468
# 1    0.168532
# Name: proportion, dtype: float64

# %% [markdown]
# #### **Logistic Binomial Regression Modeling**
# Modeling Fitting

# %%
#Creation of Train and Test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42, stratify=y)

# %%
#Fitting into Binary Logistic Regression
log_clf = LogisticRegression(random_state = 42, max_iter=500).fit(X_train, y_train)

# %%
#Present Coefficient of the Model
col_names = X_train.columns
coef_array = []
for i in range(len(X_train.columns)):
    x = log_clf.coef_[0][i]
    coef_array.append(x)
coef = pd.DataFrame(data={'Coefficient':coef_array}, index = X_train.columns)
coef['Coefficient'] = coef['Coefficient'].apply(lambda x: '{:,.5f}'.format(x))
coef.sort_values('Coefficient', ascending = False)
# Out:
#                        Coefficient
# tenure                     1.10370
# department_sales           0.04331
# department_support         0.04218
# department_technical       0.03605
# department_hr              0.01998
# average_monthly_hours      0.00361
# satisfaction_level        -4.34907
# work_accident             -1.50408
# promotion_last_5years     -1.24093
# salary                    -0.52797
# number_project            -0.48416
# department_RandD          -0.31550
# department_accounting     -0.28543
# department_management     -0.19380
# department_marketing      -0.09913
# department_IT             -0.08386
# department_product_mng    -0.08026
# last_evaluation           -0.06691

# %%
#Identify the intercept
log_clf.intercept_
# Out:
# array([-1.29562028])

# %% [markdown]
# #### **Logistic Binomial Regression Modeling**
# Model Evaluation

# %%
#Get predicted dependent Variables
y_pred = log_clf.predict(X_test)

# %%
#Create Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels = log_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= log_clf.classes_)
disp.plot(values_format='', cmap = 'Blues')
plt.show()

# %%
#Calculate Evaluation Matrics
target_names = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_test, y_pred, target_names=target_names))

model_name = 'Logistic Regression'
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred, average='weighted')
recall = metrics.recall_score(y_test, y_pred, average='weighted')
f1 = metrics.f1_score(y_test, y_pred, average='weighted')
auc = metrics.roc_auc_score(y_test, y_pred, average='weighted')

Log_reg = pd.DataFrame()
Log_reg = pd.DataFrame({'model': [model_name],
                      'precision': [precision],
                      'recall': [recall],
                      'f1': [f1],
                      'accuracy': [accuracy],
                      'AUC': [auc]
                     })
Log_reg
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.86      0.93      0.90      2321
#     Predicted would leave       0.44      0.26      0.33       471
#
#                  accuracy                           0.82      2792
#                 macro avg       0.65      0.60      0.61      2792
#              weighted avg       0.79      0.82      0.80      2792
#                  model  precision    recall        f1  accuracy       AUC
# 0  Logistic Regression   0.790556  0.819484  0.799963  0.819484  0.596967

# %% [markdown]
# #### **Logistic Binomial Regression Modeling**
# Results Interpretation

# %% [markdown]
# **Confusion Matrix:**
# 1. True Negative *(upper left)* - Correctly predicted to not leave
# 2. True Positive *(lower right)* - Correctly predicted to leave
# 3. False Positive *(upper right)* - Predicted to leave but did not leave
# 4. False Negative *(lower left)* - Predicted to not leave but left
#
# **Discussion:**
# The Binomial Logistic Regression had average scores of **79% precision, 82% recall, and 80% f1-score, 59.70% auc score**.\
# The scores for the prediction if someone would leave is much **lower** than the above scores.\
# Given an imbalance of 83-17, **auc score** is the determined metric focused on.\
# Among the independent variables included, **satisfaction level, tenure, work-accident and promotion** had the highed coefficient
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ## Classification Machine Learning Identification
# 1. **✗** Naive Bayers Classifier: hard to model due to mixture of continous and categorical features
# 2. **✓** Decision Tree Classifier: applicable
# 3. **✓** Random Forest Classifier: applicable for better management of overfitting or bias
# 4. **✓** XGBoost Classifier: applicable for better management of overfitting or bias

# %% [markdown]
# #### **Data Cleaning and Preparation**
# - Requires minimal data preparation
# - Outlier are acceptable to be included

# %%
#Copy new DataFrame for Decision Tree Classifier Modeling
df_dt_enc = df_enc.copy()

# %%
#Isolate Output Variable
y = df_dt_enc['left']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
#Isolate Predictor Features
X = df_dt_enc.drop('left', axis = 1)
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  promotion_last_5years  salary  department_IT  \
# 0       3              0                      0       0          False
# 1       6              0                      0       1          False
# 2       4              0                      0       1          False
# 3       5              0                      0       0          False
# 4       3              0                      0       0          False
#
#    department_RandD  department_accounting  department_hr  \
# ...

# %% [markdown]
# #### **Helper Function**: Results Summary

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                   'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'accuracy': 'mean_test_accuracy'
                  }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy],
                          'auc': [auc]
                        })
  
    return table

# %% [markdown]
# #### **Helper Function**: Pickle Model

# %%
# Define a path to the folder where you want to save the model
path = ''

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %% [markdown]
# ### Modeling (Decision Tree Classifier)

# %% [markdown]
# #### **Decision Tree Classifier Modeling**
# Modeling Fitting

# %%
#Creation of Train and Test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

# %%
#Fitting data into Decision Tree
tree = DecisionTreeClassifier(random_state = 42)

#Set Hyperparameters
cv_params = {'max_depth':[1,2,3,4,5,6,7,8,None],
             'min_samples_leaf':[1,2,3,4,5,6],
             'min_samples_split':[1,2,4,6,8]}
#Set Scoring
scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

#Search for best Parameter
tree_cv = GridSearchCV(tree, cv_params, scoring=scoring, cv=5, refit='roc_auc')

# %%
# %%time
tree_cv.fit(X_train, y_train)
clear_output()
# Out:
# CPU times: total: 19.3 s
# Wall time: 19.4 s

# %%
#Identify best parameters
tree_cv.best_params_
# Out:
# {'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
#Get Best AUC Score
tree_cv.best_score_
# Out:
# 0.9737700178821276

# %%
# Write pickle
write_pickle(path, tree_cv, 'tree_cv')

# %%
# Read pickle
tree_cv = read_pickle(path, 'tree_cv')

# %%
# Get all CV scores
tree_cv_results = make_results('Decision tree CV', tree_cv, 'auc')
tree_cv_results
# Out:
#               model  precision    recall        F1  accuracy      auc
# 0  Decision tree CV   0.946803  0.917605  0.931956   0.97776  0.97377

# %%
#Plot the tree
plt.figure(figsize=(85,20))
plot_tree(tree_cv.best_estimator_, max_depth=5, fontsize=14, feature_names=X.columns, 
          class_names={0:'stayed', 1:'left'}, filled=True);
plt.show()

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Modeling (Random Forest Classifier)

# %% [markdown]
# #### **Random Forest Classifier Modeling**
# Model Fitting

# %%
#Fitting data into Random Forest
rf = RandomForestClassifier(random_state = 42)

#Set Hyperparameters
cv_params = {'max_depth':[5],
             'max_features': [1.0],
             'max_samples': [0.8,0.9],
             'min_samples_leaf':[1],
             'min_samples_split':[2],
             'n_estimators':[240, 230, 220]}
#Set Scoring
scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

#Search for best Parameter
rf_cv = GridSearchCV(rf, cv_params, scoring=scoring, cv=5, refit='roc_auc')

# %%
# %%time
rf_cv.fit(X_train, y_train)
# Out:
# CPU times: total: 39.4 s
# Wall time: 39.5 s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [5], 'max_features': [1.0],
#                          'max_samples': [0.8, 0.9], 'min_samples_leaf': [1],
#                          'min_samples_split': [2],
#                          'n_estimators': [240, 230, 220]},
#              refit='roc_auc',
#              scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'])

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 1.0,
#  'max_samples': 0.8,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 240}

# %%
rf_cv.best_score_
# Out:
# 0.9815017320972969

# %%
# Write pickle
write_pickle(path, rf_cv, 'rf_cv')

# %%
# Read pickle
rf_cv = read_pickle(path, 'rf_cv')

# %%
rf_cv_results = make_results('Random Forest CV', rf_cv, 'auc')
rf_cv_results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Random Forest CV   0.948125  0.917607  0.932594  0.977983  0.981502

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Modeling (XGBoost Classifier)

# %% [markdown]
# #### **XGBoost Classifier Modeling**
# Model Fitting

# %%
#Fitting data into XGBoost
xgb = XGBClassifier(random_state = 42)

#Set Hyperparameters
cv_params = {'max_depth': [4,5],
              'min_child_weight': [1,2,3],
              'learning_rate': [0.5,0.6],
              'n_estimators': [16,17,18],
              'subsample': [0.7],
              'colsample_bytree': [0.7]
              }
#Set Scoring
scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

#Search for best Parameter
xgb_cv = GridSearchCV(xgb, cv_params, scoring=scoring, cv=5, refit='roc_auc')

# %%
# %%time
xgb_cv = xgb_cv.fit(X_train, y_train)
# Out:
# CPU times: total: 1min 25s
# Wall time: 7.59 s

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.5,
#  'max_depth': 5,
#  'min_child_weight': 2,
#  'n_estimators': 16,
#  'subsample': 0.7}

# %%
xgb_cv.best_score_
# Out:
# 0.983764973476091

# %%
# Write pickle
write_pickle(path, xgb_cv, 'xgb_cv')

# %%
# Write pickle
xgb_cv = read_pickle(path, 'xgb_cv')

# %%
xgb_cv_results = make_results('XGBoost CV', xgb_cv, 'auc')
xgb_cv_results
# Out:
#         model  precision    recall        F1  accuracy       auc
# 0  XGBoost CV   0.976527  0.915593  0.945016  0.982319  0.983765

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ## Classification Model Evaluation

# %% [markdown]
# ### **Feature Importance**

# %%
#VALUES
#Decision tree
tree_important = pd.DataFrame(tree_cv.best_estimator_.feature_importances_, 
                                 columns=['decision_tree_cv'], 
                                 index=X.columns)
tree_important = tree_important[tree_important['decision_tree_cv'] > 0.05]

#Random Forest
rf_important = pd.DataFrame(rf_cv.best_estimator_.feature_importances_, 
                                 columns=['random_forest_cv'], 
                                 index=X.columns)
rf_important = rf_important[rf_important['random_forest_cv'] > 0.05]

#XRBoost
xgb_important = pd.DataFrame(xgb_cv.best_estimator_.feature_importances_, 
                                 columns=['xgboost_cv'], 
                                 index=X.columns)
xgb_important = xgb_important[xgb_important['xgboost_cv'] > 0.05]

feat_important = pd.concat([tree_important,rf_important,xgb_important], axis = 1)
feat_important = feat_important.sort_values('xgboost_cv', ascending=False).reset_index().rename(columns={'index':'feature'})

# %%
#PLOTTED
#Melt the data for easy plotting
plt.figure(figsize=(10,6))
palette = ['#73c476','#fd8c3b','#5b3495']
feat_important_melted = pd.melt(feat_important, id_vars = 'feature', var_name = 'ML_cv', value_name = 'feat_gini_score')
sns.barplot(data=feat_important_melted, x='feat_gini_score', y='feature', hue = 'ML_cv', orient='h', palette = palette)
plt.title('Feature Importance Comparison of Machine Learning Models')
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.legend(loc = "lower right")
feat_important
# Out:
#                  feature  decision_tree_cv  random_forest_cv  xgboost_cv
# 0     satisfaction_level          0.513187          0.479385    0.305532
# 1                 tenure          0.122696          0.121723    0.260289
# 2        last_evaluation          0.173078          0.159048    0.127024
# 3         number_project          0.121938          0.166817    0.119401
# 4  average_monthly_hours          0.068409          0.072197    0.074382

# %% [markdown]
# Among the independent variables included for the Machine Learning models, the following had the highest importance score:
# - satisfaction level,
# - number of projects,
# - last_evaluation,
# - tenure and average monthly hours

# %% [markdown]
# ### **Training Metric Scores**

# %%
summary_results = pd.concat([tree_cv_results,rf_cv_results,xgb_cv_results])
summary_results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Decision tree CV   0.946803  0.917605  0.931956  0.977760  0.973770
# 0  Random Forest CV   0.948125  0.917607  0.932594  0.977983  0.981502
# 0        XGBoost CV   0.976527  0.915593  0.945016  0.982319  0.983765

# %% [markdown]
# ## Model Evaluation with Test Subset

# %%
#Helper Function to get Results
def get_scores(model_name:str, model, X_test_data, y_test_data):
    '''
    Generate a table of test scores.

    In: 
        model_name (string):  How you want your model to be named in the output table
        model:                A fit GridSearchCV object
        X_test_data:          numpy array of X_test data
        y_test_data:          numpy array of y_test data

    Out: pandas df of precision, recall, f1, accuracy, and AUC scores for your model
    '''

    preds = model.best_estimator_.predict(X_test_data)

    auc = metrics.roc_auc_score(y_test_data, preds)
    accuracy = metrics.accuracy_score(y_test_data, preds)
    precision = metrics.precision_score(y_test_data, preds)
    recall = metrics.recall_score(y_test_data, preds)
    f1 = metrics.f1_score(y_test_data, preds)

    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision], 
                          'recall': [recall],
                          'f1': [f1],
                          'accuracy': [accuracy],
                          'AUC': [auc]
                         })
  
    return table

# %%
#Confusion Matrix Comparison
fig , axes = plt.subplots(1,3,figsize = (15,4))

#Decision Tree
preds_dt = tree_cv.best_estimator_.predict(X_test)
cm_dt = confusion_matrix(y_test, preds_dt, labels=tree_cv.classes_)
disp_dt = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=tree_cv.classes_)
disp_dt.plot(values_format='', ax = axes[0], cmap = 'Greens')
axes[0].set_title('Decision Tree CV')

#Random Forest
preds_rf = rf_cv.best_estimator_.predict(X_test)
cm_rf = confusion_matrix(y_test, preds_rf, labels=rf_cv.classes_)
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=rf_cv.classes_)
disp_rf.plot(values_format='', ax = axes[1], cmap = 'Oranges')
axes[1].set_title('Random Forest CV')

#XRBoost
preds_xgb = xgb_cv.best_estimator_.predict(X_test)
cm_xgb = confusion_matrix(y_test, preds_xgb, labels=xgb_cv.classes_)
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb, display_labels=xgb_cv.classes_)
disp_xgb.plot(values_format='', ax = axes[2], cmap = 'Purples')
axes[2].set_title('XRBoost CV')
plt.show()

# %% [markdown]
# **Confusion Matrix:**
# 1. True Negative *(upper left)* - Correctly predicted to not leave
# 2. True Positive *(lower right)* - Correctly predicted to leave
# 3. False Positive *(upper right)* - Predicted to leave but did not leave
# 4. False Negative *(lower left)* - Predicted to not leave but left
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# # **E. Conclusion and Recommendation**

# %% [markdown]
# ## **Summary of Model Results Fitted with Test Data**

# %%
tree_cv_test = get_scores('Decision Tree CV Test', tree_cv, X_test, y_test)
rf_cv_test = get_scores('Random Forest CV Test', rf_cv, X_test, y_test)
xgb_cv_test = get_scores('XGBoost CV Test', xgb_cv, X_test, y_test)

summary_test = pd.concat([Log_reg,tree_cv_test,rf_cv_test,xgb_cv_test])
summary_test
# Out:
#                    model  precision    recall        f1  accuracy       AUC
# 0    Logistic Regression   0.790556  0.819484  0.799963  0.819484  0.596967
# 0  Decision Tree CV Test   0.958506  0.927711  0.942857  0.981321  0.959855
# 0  Random Forest CV Test   0.958333  0.923695  0.940695  0.980654  0.957847
# 0        XGBoost CV Test   0.978769  0.925703  0.951496  0.984323  0.960851

# %% [markdown]
# The four machine learning models showed good metric scores with the XRBoost Model having the highest Metric Scores.
# Results of the feature importance indicates that the following had the greatest impact on whether an employee leaves or stays:
# - Satisfaction Level
# - Number of Projects
# - Tenure
# - Average Monthly Hours
# - Evaluation Score

# %% [markdown]
# ## **Recommendations**
#
# **Basing from the Data Analysis the following recommendations are advised:**
# 1. Limit the number of projects assigned to an employee to 2-4 projects only.
# 2. Implement rules on work hours, either rewarding for working longer hours or cap the working hours to a reasonable amount keeping an eye on overwork signs.
# 3. Streamline evaluation scoring for employees putting more score weight on contribution and effort
# 4. Consider promotion after 4 years
# 5. Evaluate and Discuss about company culture across different departments
#
# **Further analysis:**
# 1. Consider using another variable as the output for modeling such as performance or satisfaction levels.
# 2. In-depth analysis of working over 200 hours.
